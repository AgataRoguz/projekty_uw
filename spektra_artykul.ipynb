# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import StandardScaler, LabelEncoder
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, classification_report
import itertools
from scipy import stats

# %%
from statsmodels.stats.diagnostic import lillifors

# %%
data = pd.read_excel("/Users/FeatureForest/Documents/Spektra list gatunków Fritillaria.xlsx", sheet_name='DANE KWIATÓW', delimiter=";", decimal=",")

# %%
data.head()
# Out:
#       Gatunek Kolor  Średnica  płatek
# 0  F. affinis   PUR      26.1   22.86
# 1  F. affinis   PUR       NaN   24.29
# 2  F. affinis   PUR       NaN   25.00
# 3  F. affinis   PUR       NaN   25.00
# 4  F. affinis   PUR       NaN   23.16

# %%
#retruns pollinator
def pollinator(name):
    if((name == 'F. eduardii') | (name == 'F. imperialis')):
        return "PAS"
    elif ((name == "F. recurva") | (name == "F. gentneri")):
        return "HUM"
    else:
        return "INS"

# %%
data.head()
# Out:
#       Gatunek Kolor  Średnica  płatek
# 0  F. affinis   PUR      26.1   22.86
# 1  F. affinis   PUR       NaN   24.29
# 2  F. affinis   PUR       NaN   25.00
# 3  F. affinis   PUR       NaN   25.00
# 4  F. affinis   PUR       NaN   23.16

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1606 entries, 0 to 1605
# Data columns (total 4 columns):
# Gatunek     1606 non-null object
# Kolor       1606 non-null object
# Średnica    206 non-null float64
# płatek      1146 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 50.3+ KB

# %%
data.Gatunek.unique()
# Out:
# array(['F. affinis', 'F. caucasica', 'F. crassifolia', 'F. eastwoodiae',
#        'F. eduardii', 'F. gibbosa', 'F. gracilis', 'F. graeca',
#        'F. imperialis', 'F. kotschyana', 'F. latakiensis', 'F. liliae',
#        'F. michailovskyi', 'F. meleagroides', 'F. montana',
#        'F. mutabilis', 'F. pyrenaica', 'F. pontica', 'F. raddeana',
#        'F. serpenticola', 'F. sewerzowii', 'F. stenanthera',
#        'F. tubiformis', 'F. ussuriensis', 'F. uva vulpis',
#        'F. whittallii', 'F. recurva', 'F. gentneri', 'F. ariana',
#        'F. dasyphylla', 'F. minima', 'F. thunbergii', 'F. armena '],
#       dtype=object)

# %%
#data["płatek"] = data.płatek.astype(float)

# %%
data.groupby(['Gatunek']).agg({'płatek': 'count'
                                }).reset_index()
# Out:
#              Gatunek  płatek
# 0         F. affinis       6
# 1          F. ariana       7
# 2         F. armena        6
# 3       F. caucasica      18
# 4     F. crassifolia      12
# 5      F. dasyphylla       6
# 6     F. eastwoodiae       6
# 7        F. eduardii      45
# 8        F. gentneri      85
# 9         F. gibbosa       6
# 10       F. gracilis       6
# 11         F. graeca       6
# 12     F. imperialis      46
# 13     F. kotschyana       6
# 14    F. latakiensis       4
# 15         F. liliae       6
# 16   F. meleagroides      12
# 17  F. michailovskyi     140
# 18         F. minima       6
# 19        F. montana      21
# 20      F. mutabilis      18
# 21        F. pontica      18
# 22      F. pyrenaica       6
# 23       F. raddeana     180
# 24        F. recurva       5
# 25   F. serpenticola       6
# 26     F. sewerzowii      91
# 27    F. stenanthera     195
# 28     F. thunbergii      23
# 29     F. tubiformis       6
# 30    F. ussuriensis      12
# 31     F. uva vulpis     118
# 32     F. whittallii      18

# %%
df1 = data.groupby(['Gatunek']).agg({'Średnica': 'mean', 
                                     'płatek': 'mean'
                                }).reset_index()

# %%
df1.dropna(inplace=True)

# %%
df1['Pollinator'] = df1['Gatunek'].apply(pollinator)

# %%
df1
# Out:
#              Gatunek   Średnica     płatek Pollinator
# 0         F. affinis  26.100000  23.960000        INS
# 1          F. ariana  26.390000  15.281429        INS
# 2         F. armena   10.000000  19.566667        INS
# 3       F. caucasica  27.930000  38.743889        INS
# 4     F. crassifolia  20.000000  15.772500        INS
# 5      F. dasyphylla  13.490000  15.013333        INS
# 6     F. eastwoodiae  17.000000  20.283333        INS
# 7        F. eduardii  79.786250  52.871778        PAS
# 8        F. gentneri  25.582667  28.630353        HUM
# 9         F. gibbosa  27.400000  15.116667        INS
# 10       F. gracilis  24.900000  24.038333        INS
# 11         F. graeca  12.500000  25.016667        INS
# 12     F. imperialis  66.884167  52.026739        PAS
# 13     F. kotschyana  28.400000  48.600000        INS
# 14    F. latakiensis  15.000000  13.025000        INS
# 15         F. liliae  21.600000  14.116667        INS
# 16   F. meleagroides  20.000000  29.436667        INS
# 17  F. michailovskyi  21.897917  23.005429        INS
# 18         F. minima  14.000000  17.666667        INS
# 19        F. montana  23.705000  24.269524        INS
# 20      F. mutabilis  24.000000  21.214444        INS
# 21        F. pontica  21.250000  25.872222        INS
# 22      F. pyrenaica  26.000000  37.493333        INS
# 23       F. raddeana  46.652857  33.327389        INS
# 24        F. recurva  38.040000  36.014000        HUM
# 25   F. serpenticola  14.905660  13.684591        INS
# 26     F. sewerzowii  21.658519  28.959780        INS
# 27    F. stenanthera  22.324103  18.378103        INS
# 28     F. thunbergii  44.250000  15.173913        INS
# 29     F. tubiformis  29.000000  40.483333        INS
# 30    F. ussuriensis  29.710000  21.933333        INS
# 31     F. uva vulpis  14.645882  20.783729        INS
# 32     F. whittallii  30.716667  30.667778        INS

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 32
# Data columns (total 4 columns):
# Gatunek       33 non-null object
# Średnica      33 non-null float64
# płatek        33 non-null float64
# Pollinator    33 non-null object
# dtypes: float64(2), object(2)
# memory usage: 1.3+ KB

# %%
pVals = pd.Series()
# The scipy normaltest is based on D-Agostino and Pearsons test that
# combines skew and kurtosis to produce an omnibus test of normality.
_, pVals['Omnibus']    = stats.normaltest(df1.płatek)

# Shapiro-Wilk test
_, pVals['Shapiro-Wilk']    = stats.shapiro(df1.płatek)

# Or you can check for normality with Lilliefors-test
_, pVals['Lilliefors']    = lillifors(df1.płatek)

# Alternatively with original Kolmogorov-Smirnov test
_, pVals['Kolmogorov-Smirnov']    = stats.kstest((df1.płatek-np.mean(df1.płatek))/np.std(df1.płatek,ddof=1), 'norm')

print('p-values for all {0} data points: ----------------'.format(len(df1.płatek)))
print(pVals)

if pVals['Omnibus'] > 0.05:
    print('Data are normally distributed')
# Out:
# p-values for all 33 data points: ----------------
# Omnibus               0.045419
# Shapiro-Wilk          0.003915
# Lilliefors            0.080217
# Kolmogorov-Smirnov    0.463736
# dtype: float64
# /Users/FeatureForest/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `lillifors` is deprecated, use `lilliefors` instead!
# Use lilliefors, lillifors will be removed in 0.9
# (Note: misspelling missing 'e')
#   # Remove the CWD from sys.path while we load stuff.

# %%
ins_srednica = df1.Średnica[df1.Pollinator == "INS"]
pas_srednica = df1.Średnica[df1.Pollinator == "PAS"]
hum_srednica = df1.Średnica[df1.Pollinator == "HUM"]

# %% [markdown]
# ### Testing normality srednica

# %%
pVals = pd.Series()
# The scipy normaltest is based on D-Agostino and Pearsons test that
# combines skew and kurtosis to produce an omnibus test of normality.
_, pVals['Omnibus']    = stats.normaltest(ins_srednica)

# Shapiro-Wilk test
_, pVals['Shapiro-Wilk']    = stats.shapiro(ins_srednica)

# Or you can check for normality with Lilliefors-test
_, pVals['Lilliefors']    = lillifors(ins_srednica)

# Alternatively with original Kolmogorov-Smirnov test
_, pVals['Kolmogorov-Smirnov']    = stats.kstest((ins_srednica-np.mean(ins_srednica))/np.std(ins_srednica,ddof=1), 'norm')

print('p-values for all {0} data points: ----------------'.format(len(ins_srednica)))
print(pVals)

if pVals['Omnibus'] > 0.05:
    print('Data are normally distributed')
# Out:
# p-values for all 29 data points: ----------------
# Omnibus               0.015539
# Shapiro-Wilk          0.023282
# Lilliefors            0.200000
# Kolmogorov-Smirnov    0.806033
# dtype: float64
# /Users/FeatureForest/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `lillifors` is deprecated, use `lilliefors` instead!
# Use lilliefors, lillifors will be removed in 0.9
# (Note: misspelling missing 'e')
#   # Remove the CWD from sys.path while we load stuff.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import (pairwise_tukeyhsd, MultiComparison)
from statsmodels.stats.libqsturng import psturng

# %%
df1.boxplot('Średnica', by='Pollinator')

# %% [markdown]
# ### Testing homogenity of variance (diam)

# %%
# First, check if the variances are equal, with the "Levene"-test
(W,p) = stats.levene(ins_srednica, pas_srednica, hum_srednica)
if p<0.05:
    print(('Warning: the p-value of the Levene test is <0.05: p={0}'.format(p)))
else:
    
    print('OK', p)
# Out:
# OK 0.9961632617596949

# %% [markdown]
# ### One way anova (diameter)

# %%
f, p = stats.f_oneway(ins_srednica,
                      hum_srednica,
                      pas_srednica)
 
print ('One-way ANOVA')
print ('=============')
 
print ('F value:', f)
print ('P value:', p, '\n')
# Out:
# One-way ANOVA
# =============
# F value: 33.36121306994132
# P value: 2.3654354239800988e-08

# %%
#Then, do the multiple testing
multiComp = MultiComparison(df1['Średnica'], df1['Pollinator'])

# %%
print((multiComp.tukeyhsd().summary()))
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ==============================================
# group1 group2 meandiff  lower    upper  reject
# ----------------------------------------------
#  HUM    INS   -8.5208  -23.7059  6.6643 False
#  HUM    PAS   41.5239  20.7532  62.2946  True
#  INS    PAS   50.0446  34.8595  65.2297  True
# ----------------------------------------------

# %%
ins_płatek = df1.płatek[df1.Pollinator == "INS"]
pas_płatek = df1.płatek[df1.Pollinator == "PAS"]
hum_płatek = df1.płatek[df1.Pollinator == "HUM"]

# %% [markdown]
# ### Testing homogienity of variance (thickness of petals)

# %%
# First, check if the variances are equal, with the "Levene"-test
(W,p) = stats.levene(ins_płatek, pas_płatek, hum_płatek)
if p<0.05:
    print(('Warning: the p-value of the Levene test is <0.05: p={0}'.format(p)))
else:
    
    print('OK', p)
# Out:
# OK 0.2821635786287848

# %% [markdown]
# ### One way anova (thickness)

# %%
f, p = stats.f_oneway(ins_płatek,
                      hum_płatek,
                      pas_płatek)
 
print ('One-way ANOVA')
print ('=============')
 
print ('F value:', f)
print ('P value:', p, '\n')
# Out:
# One-way ANOVA
# =============
# F value: 10.41567406430666
# P value: 0.00036715073351564965

# %%
#Then, do the multiple testing
multiComp = MultiComparison(df1['płatek'], df1['Pollinator'])

# %%
print((multiComp.tukeyhsd().summary()))
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ==============================================
# group1 group2 meandiff  lower    upper  reject
# ----------------------------------------------
#  HUM    INS   -8.4986  -24.3706  7.3735 False
#  HUM    PAS   20.1271  -1.5833  41.8374 False
#  INS    PAS   28.6256  12.7536  44.4977  True
# ----------------------------------------------

# %%
df1[df1.Pollinator=='PAS']
# Out:
#           Gatunek   Średnica     płatek Pollinator
# 7     F. eduardii  79.786250  52.871778        PAS
# 12  F. imperialis  66.884167  52.026739        PAS

# %%
#Create a boxplot
df1.boxplot('płatek', by='Pollinator', figsize=(12, 8))

# %%
grub = pd.read_excel("/Users/FeatureForest/Documents/Spektra list gatunków Fritillaria.xlsx", sheet_name='grubość płatka', delimiter=";", decimal=",")

# %%
grub.drop(grub.columns[1:23], axis=1, inplace=True)

# %%
grub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 38 entries, 1.0 to 37.0
# Data columns (total 4 columns):
# sp             38 non-null object
# μm             38 non-null float64
# sd             38 non-null float64
# Unnamed: 25    38 non-null int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.5+ KB

# %%
grub.rename(index=str, columns={"μm": "grub", "Unnamed: 25": "N"}, inplace=True)

# %%
grub.reset_index(inplace=True)

# %%
grub.drop(grub.columns[0], axis=1, inplace=True)

# %%
grub.head()
# Out:
#            sp        grub          sd  N
# 0  F. affinis  504.600000   49.106415  5
# 1    F. amana  300.675926   19.680200  4
# 2   F. armena  620.500218   22.242582  5
# 3   F. ariana  427.061799   57.074561  7
# 4    F. aurea  714.772407  107.565515  8

# %%
#Reflectance data
xls = pd.ExcelFile('/Users/FeatureForest/Documents/Fritillaria Warsaw.xlsx')

# %%
names = xls.sheet_names

# %%
#list of analysed species
species = ["F. imperialis","F. michailovskyi",'F. whittallii','F. tubiformis','F. gracilis',
           'F. eduardii','F. minima','F. thunbergii','F. eastwoodiae', "F. liliaceae", 
           "F. liliaceae", "F. kurdica",'F. pyrenaica', 'F. pontica', 'F. thunbergii',
           'F. uva vulpis', 'F. affinis','F. montana',  'F. aryiana', 'F. dasyphylla', 
           'F. verticillata','F. serpenticola', 'F. mutabilis', 'F. raddeana', 'F. graeca', 
           'F. caucasica', 'F. gibbosa', 'F. armena','F. stenanthera','F. ussuriensis',
           'F. kotschyana','F. meleagris', "F. michailovskyi", 'F. latakesis', 'F. gentneri',
          'F. recurva', 'F. sewerzowii', 'F.', 'F. messanensis']

# %%
import re

# %%
outside = []
pattern = ".+ou.+"
outside = [x for x in names if re.match(pattern,x)]

# %%
#removing reflectance in other than red
indexes = [1,3,15,17,20,35,39,40]
for index in sorted(indexes, reverse=True):
    del outside[index]

# %%
#outside

# %%
indexes_outside = []
for i in range(len(outside)):
    indexes_outside.append(names.index(outside[i]))

sheets_outside = []
for i in range(len(outside)):
    sheet = xls.parse(indexes_outside[i])
    sheets_outside.append(sheet)

# %%
#returns UV & visible spectrum
for i in range(len(sheets_outside)):
    sheets_outside[i] = sheets_outside[i][(sheets_outside[i].nm > 300) & (sheets_outside[i].nm < 700)]

# %%
#columns wiht reflectancy value
columns_ref = sheets_outside[0].columns[1::2]

# %%
#returns mean of wavelengths (relative)
for i in range(len(sheets_outside)):
    sheets_outside[i] = sheets_outside[i].assign(mean=sheets_outside[i][columns_ref].mean(axis=1)/1000)

# %%
from functools import reduce

# %%
numbers = []
for i in range(1,38):
    numbers.append("Sp"+str(i))
nms = list(zip(numbers, species))
outside_species = []
for i in range(9):
    outside_species.append(reduce(lambda a, kv: a.replace(*kv), nms, outside[i]))

# %%
for i in range(9, len(outside)):
    outside_species.append(reduce(lambda a, kv: a.replace(*kv), nms[9:], outside[i]))

# %%
#sheets_outside[0]

# %%
#(outside_species)

# %%
len(species)
# Out:
# 39

# %%
srednia = []
for i in range(len(sheets_outside)):
    srednia.append(sheets_outside[i]['mean'].mean())

# %%
len(srednia)
# Out:
# 39

# %%
#srednia

# %%
reflektancja = pd.DataFrame(
    {'Gatunek': species,
     'srednia': srednia
    })

# %%
#reflektancja

# %%
grub
# Out:
#                   sp        grub          sd   N
# 0         F. affinis  504.600000   49.106415   5
# 1           F. amana  300.675926   19.680200   4
# 2          F. armena  620.500218   22.242582   5
# 3          F. ariana  427.061799   57.074561   7
# 4           F. aurea  714.772407  107.565515   8
# 5       F. caucasica  632.798222   76.771188  10
# 6      F. dasyphylla  557.800000   45.004000   5
# 7     F. eastwoodiae  463.812778   47.375421   8
# 8        F. eduardii  964.971287  134.963390  19
# 9        F. gentneri  543.723148  140.982127   8
# 10        F. gibbosa  515.056667  126.166533   6
# 11       F. gracilis  513.899290   98.215369  12
# 12         F. graeca  501.809832  101.758327  11
# 13     F. imperialis  856.232222  117.473314   9
# 14     F. kotschyana  500.691077   49.106247  11
# 15    F. crassifolia  459.110000   52.165361   9
# 16    F. latakiensis  565.680000   48.370214   5
# 17      F. liliaceae  527.744370   47.781845   5
# 18      F. meleagris  200.146000  101.398801   5
# 19  F. michailovskyi  383.140741   19.799688   5
# 20         F. minima  438.770370   33.114669   5
# 21         F. minuta  490.138827  103.317203   6
# 22        F. montana  515.128000   44.084437   5
# 23      F. mutabilis  495.704306   98.947825   8
# 24        F. persica  730.790000  184.881017   9
# 25        F. pontica  586.565679   93.171600   9
# 26      F. pyrenaica  457.868519   33.173925   5
# 27       F. raddeana  960.206118   87.985344   5
# 28        F. recurva  393.159909   50.500404   6
# 29   F. serpenticola  141.892000   35.581092   5
# 30     F. sewerzowii  467.445705   97.213681   8
# 31    F. stenanthera  459.105000   44.380828   4
# 32     F. thunbergii  470.000000    0.000000   1
# 33     F. tubiformis  678.394099   99.552051   7
# 34    F. ussuriensis  447.672151   62.341572  12
# 35     F. uva vulpis  831.997221  131.645469  11
# 36   F. verticillata  430.045624   85.151467   7
# 37     F. whittallii  763.310588   74.625613   8

# %%
df = pd.merge(reflektancja, grub, how='inner', left_on='Gatunek', right_on='sp')

# %%
df
# Out:
#              Gatunek    srednia                sp        grub          sd   N
# 0      F. imperialis  36.742887     F. imperialis  856.232222  117.473314   9
# 1   F. michailovskyi  13.053858  F. michailovskyi  383.140741   19.799688   5
# 2   F. michailovskyi   3.391066  F. michailovskyi  383.140741   19.799688   5
# 3      F. whittallii   3.288491     F. whittallii  763.310588   74.625613   8
# 4      F. tubiformis  22.353346     F. tubiformis  678.394099   99.552051   7
# 5        F. gracilis  11.291390       F. gracilis  513.899290   98.215369  12
# 6        F. eduardii  12.215779       F. eduardii  964.971287  134.963390  19
# 7          F. minima  26.406632         F. minima  438.770370   33.114669   5
# 8      F. thunbergii  15.297238     F. thunbergii  470.000000    0.000000   1
# 9      F. thunbergii  11.317872     F. thunbergii  470.000000    0.000000   1
# 10    F. eastwoodiae   5.944222    F. eastwoodiae  463.812778   47.375421   8
# 11      F. liliaceae  42.457235      F. liliaceae  527.744370   47.781845   5
# 12      F. liliaceae  23.506989      F. liliaceae  527.744370   47.781845   5
# 13      F. pyrenaica  23.963595      F. pyrenaica  457.868519   33.173925   5
# 14        F. pontica   3.429739        F. pontica  586.565679   93.171600   9
# 15     F. uva vulpis   8.567080     F. uva vulpis  831.997221  131.645469  11
# 16        F. affinis   4.991692        F. affinis  504.600000   49.106415   5
# 17        F. montana  27.824427        F. montana  515.128000   44.084437   5
# 18     F. dasyphylla  25.952136     F. dasyphylla  557.800000   45.004000   5
# 19   F. verticillata  37.171101   F. verticillata  430.045624   85.151467   7
# 20   F. serpenticola  13.082361   F. serpenticola  141.892000   35.581092   5
# 21      F. mutabilis  32.003936      F. mutabilis  495.704306   98.947825   8
# 22       F. raddeana  22.247336       F. raddeana  960.206118   87.985344   5
# 23         F. graeca   4.811848         F. graeca  501.809832  101.758327  11
# 24      F. caucasica  10.953882      F. caucasica  632.798222   76.771188  10
# 25        F. gibbosa  53.215518        F. gibbosa  515.056667  126.166533   6
# 26         F. armena  14.747500         F. armena  620.500218   22.242582   5
# 27    F. stenanthera  29.286639    F. stenanthera  459.105000   44.380828   4
# 28    F. ussuriensis  13.371892    F. ussuriensis  447.672151   62.341572  12
# 29     F. kotschyana   9.266037     F. kotschyana  500.691077   49.106247  11
# 30      F. meleagris   5.443289      F. meleagris  200.146000  101.398801   5
# 31       F. gentneri  14.087927       F. gentneri  543.723148  140.982127   8
# 32        F. recurva   8.308935        F. recurva  393.159909   50.500404   6
# 33     F. sewerzowii  17.767391     F. sewerzowii  467.445705   97.213681   8

# %% [markdown]
# ### Correlation mean reflectance vs. thickness of petals

# %%
df['srednia'].corr(df['grub'])
# Out:
# 0.08368340859752459

# %%
#retruns pollinator
def pollinator(name):
    if((name == 'F. eduardii') | (name == 'F. imperialis')):
        return "PAS"
    elif ((name == "F. recurva") | (name == "F. gentneri")):
        return "HUM"
    else:
        return "INS"

# %%
df['Pollinator'] = df['Gatunek'].apply(pollinator)

# %%
df
# Out:
#              Gatunek    srednia                sp        grub          sd   N  \
# 0      F. imperialis  36.742887     F. imperialis  856.232222  117.473314   9
# 1   F. michailovskyi  13.053858  F. michailovskyi  383.140741   19.799688   5
# 2   F. michailovskyi   3.391066  F. michailovskyi  383.140741   19.799688   5
# 3      F. whittallii   3.288491     F. whittallii  763.310588   74.625613   8
# 4      F. tubiformis  22.353346     F. tubiformis  678.394099   99.552051   7
# 5        F. gracilis  11.291390       F. gracilis  513.899290   98.215369  12
# 6        F. eduardii  12.215779       F. eduardii  964.971287  134.963390  19
# 7          F. minima  26.406632         F. minima  438.770370   33.114669   5
# 8      F. thunbergii  15.297238     F. thunbergii  470.000000    0.000000   1
# 9      F. thunbergii  11.317872     F. thunbergii  470.000000    0.000000   1
# 10    F. eastwoodiae   5.944222    F. eastwoodiae  463.812778   47.375421   8
# 11      F. liliaceae  42.457235      F. liliaceae  527.744370   47.781845   5
# 12      F. liliaceae  23.506989      F. liliaceae  527.744370   47.781845   5
# 13      F. pyrenaica  23.963595      F. pyrenaica  457.868519   33.173925   5
# 14        F. pontica   3.429739        F. pontica  586.565679   93.171600   9
# 15     F. uva vulpis   8.567080     F. uva vulpis  831.997221  131.645469  11
# 16        F. affinis   4.991692        F. affinis  504.600000   49.106415   5
# 17        F. montana  27.824427        F. montana  515.128000   44.084437   5
# 18     F. dasyphylla  25.952136     F. dasyphylla  557.800000   45.004000   5
# 19   F. verticillata  37.171101   F. verticillata  430.045624   85.151467   7
# 20   F. serpenticola  13.082361   F. serpenticola  141.892000   35.581092   5
# 21      F. mutabilis  32.003936      F. mutabilis  495.704306   98.947825   8
# 22       F. raddeana  22.247336       F. raddeana  960.206118   87.985344   5
# 23         F. graeca   4.811848         F. graeca  501.809832  101.758327  11
# 24      F. caucasica  10.953882      F. caucasica  632.798222   76.771188  10
# 25        F. gibbosa  53.215518        F. gibbosa  515.056667  126.166533   6
# 26         F. armena  14.747500         F. armena  620.500218   22.242582   5
# 27    F. stenanthera  29.286639    F. stenanthera  459.105000   44.380828   4
# 28    F. ussuriensis  13.371892    F. ussuriensis  447.672151   62.341572  12
# 29     F. kotschyana   9.266037     F. kotschyana  500.691077   49.106247  11
# 30      F. meleagris   5.443289      F. meleagris  200.146000  101.398801   5
# 31       F. gentneri  14.087927       F. gentneri  543.723148  140.982127   8
# 32        F. recurva   8.308935        F. recurva  393.159909   50.500404   6
# 33     F. sewerzowii  17.767391     F. sewerzowii  467.445705   97.213681   8
#
#    Pollinator
# 0         PAS
# 1         INS
# 2         INS
# 3         INS
# 4         INS
# 5         INS
# 6         PAS
# 7         INS
# 8         INS
# 9         INS
# 10        INS
# 11        INS
# 12        INS
# 13        INS
# 14        INS
# 15        INS
# 16        INS
# 17        INS
# 18        INS
# 19        INS
# 20        INS
# 21        INS
# 22        INS
# 23        INS
# 24        INS
# 25        INS
# 26        INS
# 27        INS
# 28        INS
# 29        INS
# 30        INS
# 31        HUM
# 32        HUM
# 33        INS

# %% [markdown]
# ### Correlation mean reflectance vs petals thickness

# %% [markdown]
# * insect flowers

# %%
ins = df[df.Pollinator == "INS"]

# %%
ins['srednia'].corr(ins['grub'])
# Out:
# 0.01962966684566265

# %% [markdown]
# * hummingbird flowers

# %%
hum = df[df.Pollinator == "HUM"]

# %%
hum['srednia'].corr(hum['grub'])
# Out:
# 1.0

# %% [markdown]
# * passerine flowers

# %%
pas = df[df.Pollinator == "PAS"]
pas['srednia'].corr(pas['grub'])
# Out:
# -1.0

# %%
df = pd.merge(df1, grub, how='inner', left_on='Gatunek', right_on='sp')

# %%
df1.Gatunek.unique()
# Out:
# array(['F. affinis', 'F. ariana', 'F. armena ', 'F. caucasica',
#        'F. crassifolia', 'F. dasyphylla', 'F. eastwoodiae', 'F. eduardii',
#        'F. gentneri', 'F. gibbosa', 'F. gracilis', 'F. graeca',
#        'F. imperialis', 'F. kotschyana', 'F. latakiensis', 'F. liliae',
#        'F. meleagroides', 'F. michailovskyi', 'F. minima', 'F. montana',
#        'F. mutabilis', 'F. pontica', 'F. pyrenaica', 'F. raddeana',
#        'F. recurva', 'F. serpenticola', 'F. sewerzowii', 'F. stenanthera',
#        'F. thunbergii', 'F. tubiformis', 'F. ussuriensis',
#        'F. uva vulpis', 'F. whittallii'], dtype=object)

# %%
grub.sp.unique()
# Out:
# array(['F. affinis', 'F. amana', 'F. armena', 'F. ariana', 'F. aurea',
#        'F. caucasica', 'F. dasyphylla', 'F. eastwoodiae', 'F. eduardii',
#        'F. gentneri', 'F. gibbosa', 'F. gracilis', 'F. graeca',
#        'F. imperialis', 'F. kotschyana', 'F. crassifolia',
#        'F. latakiensis', 'F. liliaceae', 'F. meleagris',
#        'F. michailovskyi', 'F. minima', 'F. minuta', 'F. montana',
#        'F. mutabilis', 'F. persica', 'F. pontica', 'F. pyrenaica',
#        'F. raddeana', 'F. recurva', 'F. serpenticola', 'F. sewerzowii',
#        'F. stenanthera', 'F. thunbergii', 'F. tubiformis',
#        'F. ussuriensis', 'F. uva vulpis', 'F. verticillata',
#        'F. whittallii'], dtype=object)

# %%
df
# Out:
#              Gatunek   Średnica     płatek Pollinator                sp  \
# 0         F. affinis  26.100000  23.960000        INS        F. affinis
# 1          F. ariana  26.390000  15.281429        INS         F. ariana
# 2       F. caucasica  27.930000  38.743889        INS      F. caucasica
# 3     F. crassifolia  20.000000  15.772500        INS    F. crassifolia
# 4      F. dasyphylla  13.490000  15.013333        INS     F. dasyphylla
# 5     F. eastwoodiae  17.000000  20.283333        INS    F. eastwoodiae
# 6        F. eduardii  79.786250  52.871778        PAS       F. eduardii
# 7        F. gentneri  25.582667  28.630353        HUM       F. gentneri
# 8         F. gibbosa  27.400000  15.116667        INS        F. gibbosa
# 9        F. gracilis  24.900000  24.038333        INS       F. gracilis
# 10         F. graeca  12.500000  25.016667        INS         F. graeca
# 11     F. imperialis  66.884167  52.026739        PAS     F. imperialis
# 12     F. kotschyana  28.400000  48.600000        INS     F. kotschyana
# 13    F. latakiensis  15.000000  13.025000        INS    F. latakiensis
# 14  F. michailovskyi  21.897917  23.005429        INS  F. michailovskyi
# 15         F. minima  14.000000  17.666667        INS         F. minima
# 16        F. montana  23.705000  24.269524        INS        F. montana
# 17      F. mutabilis  24.000000  21.214444        INS      F. mutabilis
# 18        F. pontica  21.250000  25.872222        INS        F. pontica
# 19      F. pyrenaica  26.000000  37.493333        INS      F. pyrenaica
# 20       F. raddeana  46.652857  33.327389        INS       F. raddeana
# 21        F. recurva  38.040000  36.014000        HUM        F. recurva
# 22   F. serpenticola  14.905660  13.684591        INS   F. serpenticola
# 23     F. sewerzowii  21.658519  28.959780        INS     F. sewerzowii
# 24    F. stenanthera  22.324103  18.378103        INS    F. stenanthera
# 25     F. thunbergii  44.250000  15.173913        INS     F. thunbergii
# 26     F. tubiformis  29.000000  40.483333        INS     F. tubiformis
# 27    F. ussuriensis  29.710000  21.933333        INS    F. ussuriensis
# 28     F. uva vulpis  14.645882  20.783729        INS     F. uva vulpis
# 29     F. whittallii  30.716667  30.667778        INS     F. whittallii
#
#           grub          sd   N
# 0   504.600000   49.106415   5
# 1   427.061799   57.074561   7
# 2   632.798222   76.771188  10
# 3   459.110000   52.165361   9
# 4   557.800000   45.004000   5
# 5   463.812778   47.375421   8
# 6   964.971287  134.963390  19
# 7   543.723148  140.982127   8
# 8   515.056667  126.166533   6
# 9   513.899290   98.215369  12
# 10  501.809832  101.758327  11
# 11  856.232222  117.473314   9
# 12  500.691077   49.106247  11
# 13  565.680000   48.370214   5
# 14  383.140741   19.799688   5
# 15  438.770370   33.114669   5
# 16  515.128000   44.084437   5
# 17  495.704306   98.947825   8
# 18  586.565679   93.171600   9
# 19  457.868519   33.173925   5
# 20  960.206118   87.985344   5
# 21  393.159909   50.500404   6
# 22  141.892000   35.581092   5
# 23  467.445705   97.213681   8
# 24  459.105000   44.380828   4
# 25  470.000000    0.000000   1
# 26  678.394099   99.552051   7
# 27  447.672151   62.341572  12
# 28  831.997221  131.645469  11
# 29  763.310588   74.625613   8

# %%
col = {'INS':'#ffee84', 'PAS':'#007800', 'HUM':"#e5247e"}
df["colors"] = df.Pollinator.apply(lambda x: col[x])

# %%
labels =[]
sns.set_style("white")
for key, value in col.items():
    labels.append(key)
    plt.scatter(x = df.Średnica[df.Pollinator == key], y = df.płatek[df.Pollinator == key],
            s = np.array(df.grub[df.Pollinator == key])/2, 
            c = df.colors[df.Pollinator == key], alpha=0.7, edgecolors='black')

#plt.yscale('log')
plt.xscale('log') 
plt.xlabel('Flower entrance diameter (log scale)')
plt.ylabel('Petal length')
plt.title('Petal length vs flower entrance diameter', fontsize=18)
plt.xlim(xmax=108)

#plt.xticks([1000,10000,100000], ['1k','10k','100k'])
plt.text(75, 48, 'F.imperialis')
plt.text(50, 54.5, 'F.eduardi')
lgnd = plt.legend(labels, title='Color by pollinator')
for i in range(len(col)):
    lgnd.legendHandles[i]._sizes = [60]

plt.text(12.1,40, "Size by petal thickness")
plt.scatter(14.4, 37, s=100, c = 'white', edgecolors='k')
plt.text(16, 36,  r'$50 \mu m$')
# Show the plot

plt.savefig("/Users/FeatureForest/Documents/petal.jpg", dpi=1200)
plt.show()
